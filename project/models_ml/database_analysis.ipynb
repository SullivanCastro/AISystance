# %%
import pandas as pd

# %%
df = pd.read_excel('Bridge_Database.xlsx', engine='openpyxl', sheet_name='Data', skiprows=[2], header=[1], index_col=[0]) 
df.dropna(axis=1, inplace=True)
df
# Out:
#                                                     Country Alignment type  \
# Villingili bridge_1                                 Maldive           Road
# Villingili bridge_2                                 Maldive           Road
# Villingili bridge_3                                 Maldive           Road
# Villingili bridge_4                                 Maldive           Road
# Puente diagonal de la defensoresy calzada zarag...   Mexico           Road
# Puente diagonal de la defensoresy calzada zarag...   Mexico           Road
#
#                                                    Obstacle Crossed  \
# Villingili bridge_1                                   Gen. Elevated
# Villingili bridge_2                                            Road
# Villingili bridge_3                                   Navigational
# Villingili bridge_4                                   Gen. Elevated
# Puente diagonal de la defensoresy calzada zarag...          Utility
# ...

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['Country', 'Alignment type', 'Obstacle Crossed',
#        'Greenfield / Brownfield', 'Vertical alignment type',
#        'Horizontal alignment type', 'Bridge type', 'Aesthetic importance',
#        'Design code', 'Deck material', 'Deck type', 'Deck Post tensioned',
#        'Longitudinal Direction', 'Transverse Direction',
#        'Deck construction method', 'Deck depth type\nconst / var',
#        'Joint location', 'Bearing articulation longitudinal', 'Pier type',
#        'Pier material', 'Pier height', 'Abutment and wingwall material',
#        'Abutment and walls height', 'Foundation location', 'Support Type',
#        'Foundation type', 'Piles Type'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, Villingili bridge_1 to Puente diagonal de la defensoresy calzada zaragoza_2
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        6 non-null      object
#  1   Alignment type                 6 non-null      object
#  2   Obstacle Crossed               6 non-null      object
#  3   Greenfield / Brownfield        6 non-null      object
#  4   Functional section width       6 non-null      float64
#  5   Vertical alignment type        6 non-null      object
#  6   Horizontal alignment type      6 non-null      object
#  7   Alignment to FGL (max)         6 non-null      float64
#  8   Alignment to FGL (min)         6 non-null      float64
#  9   Bridge type                    6 non-null      object
#  10  Total Length                   6 non-null      float64
# ...

# %%
df.describe()
# Out:
#        Functional section width  Alignment to FGL (max)  \
# count                  6.000000                6.000000
# mean                  21.300667              739.906000
# std                    3.825088             1125.960373
# min                   17.600000                6.135000
# 25%                   18.280000               12.171750
# 50%                   20.320000               17.923000
# 75%                   24.505000             1647.131000
# max                   26.064000             2197.000000
#
#        Alignment to FGL (min)  Total Length  Span no  Pylon no.  Piers no.  \
# count                6.000000      6.000000  6.00000   6.000000   6.000000
# mean               734.436500    240.633333  4.00000   0.500000   4.333333
# std               1124.732428    161.929450  1.67332   1.224745   1.966384
# min                  4.335000     36.000000  2.00000   0.000000   2.000000
# 25%                  7.276000    125.450000  3.00000   0.000000   3.000000
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
encoded_categories = label_encoder.fit_transform(df.Country)
df.Country = encoded_categories

# %%
string_columns = df.select_dtypes(include=['object']).columns
encoded_categories = label_encoder.fit_transform(string_columns)
df[string_columns] = encoded_categories

# %%
df
# Out:
#                                                     Country Alignment type  \
# Villingili bridge_1                                       0           Road
# Villingili bridge_2                                       0           Road
# Villingili bridge_3                                       0           Road
# Villingili bridge_4                                       0           Road
# Puente diagonal de la defensoresy calzada zarag...        1           Road
# Puente diagonal de la defensoresy calzada zarag...        1           Road
#
#                                                    Obstacle Crossed  \
# Villingili bridge_1                                   Gen. Elevated
# Villingili bridge_2                                            Road
# Villingili bridge_3                                   Navigational
# Villingili bridge_4                                   Gen. Elevated
# Puente diagonal de la defensoresy calzada zarag...          Utility
# ...

# %%
encoded_categorieslabel_mapping = {i: label for i, label in enumerate(label_encoder.classes_)}
encoded_categorieslabel_mapping
# Out:
# {0: 'Alignment type',
#  1: 'Bridge type',
#  2: 'Country',
#  3: 'Deck Post tensioned',
#  4: 'Deck construction method',
#  5: 'Deck depth type\nconst / var',
#  6: 'Deck material',
#  7: 'Deck type',
#  8: 'Foundation location',
#  9: 'Foundation type',
#  10: 'Greenfield / Brownfield',
#  11: 'Horizontal alignment type',
#  12: 'Longitudinal Direction',
#  13: 'Obstacle Crossed',
#  14: 'Pier height',
#  15: 'Pier material',
#  16: 'Pier type',
#  17: 'Piles Type',
#  18: 'Support Type',
#  19: 'Transverse Direction',
#  20: 'Vertical alignment type'}
